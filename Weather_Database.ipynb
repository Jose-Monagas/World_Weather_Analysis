# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 767

# %%
# Import requests
import requests
# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=4d21a93a95b364b792ac8db63ea5cb91

# %%
# Create an empty list to hold the weather data.
city_data = list()
# Print the beginning of the logging 
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list 
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set the numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_current_description})

    # If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | yellowknife
# Processing Record 2 of Set 1 | mar del plata
# Processing Record 3 of Set 1 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 1 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 1 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 1 | rawannawi
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 1 | puerto ayora
# Processing Record 8 of Set 1 | kutum
# Processing Record 9 of Set 1 | imbituba
# Processing Record 10 of Set 1 | qaanaaq
# Processing Record 11 of Set 1 | avera
# Processing Record 12 of Set 1 | rawson
# Processing Record 13 of Set 1 | saldanha
# Processing Record 14 of Set 1 | richards bay
# Processing Record 15 of Set 1 | victoria
# Processing Record 16 of Set 1 | ranong
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | imeni poliny osipenko
# Processing Record 20 of Set 1 | haines junction
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | yantongshan
# Processing Record 23 of Set 1 | synya
# Processing Record 24 of Set 1 | batticaloa
# Processing Record 25 of Set 1 | vaini
# Processing Record 26 of Set 1 | georgetown
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | ushuaia
# Processing Record 29 of Set 1 | poum
# Processing Record 30 of Set 1 | east london
# Processing Record 31 of Set 1 | butaritari
# Processing Record 32 of Set 1 | dikson
# Processing Record 33 of Set 1 | tiksi
# Processing Record 34 of Set 1 | katsuura
# Processing Record 35 of Set 1 | pacifica
# Processing Record 36 of Set 1 | longyearbyen
# Processing Record 37 of Set 1 | iqaluit
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | dedovichi
# Processing Record 40 of Set 1 | ketchikan
# Processing Record 41 of Set 1 | nikolskoye
# Processing Record 42 of Set 1 | dingle
# Processing Record 43 of Set 1 | hilo
# Processing Record 44 of Set 1 | severo-kurilsk
# Processing Record 45 of Set 1 | provideniya
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | shingu
# Processing Record 48 of Set 1 | safford
# Processing Record 49 of Set 1 | vilhena
# Processing Record 50 of Set 1 | aripuana
# Processing Record 1 of Set 2 | atuona
# Processing Record 2 of Set 2 | maceio
# Processing Record 3 of Set 2 | guisa
# Processing Record 4 of Set 2 | virginia beach
# Processing Record 5 of Set 2 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 2 | new norfolk
# Processing Record 7 of Set 2 | uglegorsk
# Processing Record 8 of Set 2 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | matara
# Processing Record 11 of Set 2 | ushtobe
# Processing Record 12 of Set 2 | mwense
# Processing Record 13 of Set 2 | louisbourg
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 2 | ajka
# Processing Record 15 of Set 2 | kaitangata
# Processing Record 16 of Set 2 | kununurra
# Processing Record 17 of Set 2 | coquimbo
# Processing Record 18 of Set 2 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 2 | anadyr
# Processing Record 20 of Set 2 | narsaq
# Processing Record 21 of Set 2 | arraial do cabo
# Processing Record 22 of Set 2 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 2 | deputatskiy
# Processing Record 24 of Set 2 | albany
# Processing Record 25 of Set 2 | lebu
# Processing Record 26 of Set 2 | tabas
# Processing Record 27 of Set 2 | karratha
# Processing Record 28 of Set 2 | belem de sao francisco
# Processing Record 29 of Set 2 | hervey bay
# Processing Record 30 of Set 2 | iskateley
# Processing Record 31 of Set 2 | talnakh
# Processing Record 32 of Set 2 | tilichiki
# Processing Record 33 of Set 2 | hovd
# Processing Record 34 of Set 2 | damaturu
# Processing Record 35 of Set 2 | khatanga
# Processing Record 36 of Set 2 | beloha
# Processing Record 37 of Set 2 | husavik
# Processing Record 38 of Set 2 | san quintin
# Processing Record 39 of Set 2 | nalut
# Processing Record 40 of Set 2 | bocaiuva
# Processing Record 41 of Set 2 | abu samrah
# Processing Record 42 of Set 2 | okoneshnikovo
# Processing Record 43 of Set 2 | carnot
# Processing Record 44 of Set 2 | srednekolymsk
# Processing Record 45 of Set 2 | ribeira grande
# Processing Record 46 of Set 2 | athabasca
# Processing Record 47 of Set 2 | kailua
# Processing Record 48 of Set 2 | mataura
# Processing Record 49 of Set 2 | nachingwea
# Processing Record 50 of Set 2 | bathsheba
# Processing Record 1 of Set 3 | bengkulu
# Processing Record 2 of Set 3 | faanui
# Processing Record 3 of Set 3 | tessalit
# Processing Record 4 of Set 3 | rasra
# Processing Record 5 of Set 3 | tautira
# Processing Record 6 of Set 3 | geraldton
# Processing Record 7 of Set 3 | busselton
# Processing Record 8 of Set 3 | touros
# Processing Record 9 of Set 3 | tshikapa
# Processing Record 10 of Set 3 | sao joao da barra
# Processing Record 11 of Set 3 | kamenskoye
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 3 | bethel
# Processing Record 13 of Set 3 | mahebourg
# Processing Record 14 of Set 3 | codrington
# Processing Record 15 of Set 3 | mayya
# Processing Record 16 of Set 3 | chuy
# Processing Record 17 of Set 3 | ca mau
# Processing Record 18 of Set 3 | dogondoutchi
# Processing Record 19 of Set 3 | longlac
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 3 | saint-philippe
# Processing Record 21 of Set 3 | huilong
# Processing Record 22 of Set 3 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | labutta
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 3 | itarema
# Processing Record 26 of Set 3 | sumter
# Processing Record 27 of Set 3 | muros
# Processing Record 28 of Set 3 | dali
# Processing Record 29 of Set 3 | ixtapa
# Processing Record 30 of Set 3 | samarai
# Processing Record 31 of Set 3 | vostok
# Processing Record 32 of Set 3 | portland
# Processing Record 33 of Set 3 | bakchar
# Processing Record 34 of Set 3 | noumea
# Processing Record 35 of Set 3 | suarez
# Processing Record 36 of Set 3 | kruisfontein
# Processing Record 37 of Set 3 | kapaa
# Processing Record 38 of Set 3 | castro
# Processing Record 39 of Set 3 | cherskiy
# Processing Record 40 of Set 3 | praia
# Processing Record 41 of Set 3 | lodwar
# Processing Record 42 of Set 3 | te anau
# Processing Record 43 of Set 3 | arlit
# Processing Record 44 of Set 3 | belaya gora
# Processing Record 45 of Set 3 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 46 of Set 3 | cabo san lucas
# Processing Record 47 of Set 3 | mandali
# Processing Record 48 of Set 3 | kaabong
# Processing Record 49 of Set 3 | neepawa
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | wulanhaote
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 4 | mount isa
# Processing Record 3 of Set 4 | smithers
# Processing Record 4 of Set 4 | bluff
# Processing Record 5 of Set 4 | mayahi
# Processing Record 6 of Set 4 | sur
# Processing Record 7 of Set 4 | junction city
# Processing Record 8 of Set 4 | pahrump
# Processing Record 9 of Set 4 | sorong
# Processing Record 10 of Set 4 | salalah
# Processing Record 11 of Set 4 | zyryanka
# Processing Record 12 of Set 4 | tuatapere
# Processing Record 13 of Set 4 | dunedin
# Processing Record 14 of Set 4 | the pas
# Processing Record 15 of Set 4 | utete
# Processing Record 16 of Set 4 | tual
# Processing Record 17 of Set 4 | torrington
# Processing Record 18 of Set 4 | mae hong son
# Processing Record 19 of Set 4 | bonnyville
# Processing Record 20 of Set 4 | torbay
# Processing Record 21 of Set 4 | bonavista
# Processing Record 22 of Set 4 | lata
# Processing Record 23 of Set 4 | antalaha
# Processing Record 24 of Set 4 | norman wells
# Processing Record 25 of Set 4 | la ronge
# Processing Record 26 of Set 4 | vila velha
# Processing Record 27 of Set 4 | le mars
# Processing Record 28 of Set 4 | vanimo
# Processing Record 29 of Set 4 | asilah
# Processing Record 30 of Set 4 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 31 of Set 4 | port lincoln
# Processing Record 32 of Set 4 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 4 | tasiilaq
# Processing Record 34 of Set 4 | waingapu
# Processing Record 35 of Set 4 | luanda
# Processing Record 36 of Set 4 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 4 | hobart
# Processing Record 38 of Set 4 | ust-kamchatsk
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 4 | bambous virieux
# Processing Record 40 of Set 4 | port elizabeth
# Processing Record 41 of Set 4 | sorland
# Processing Record 42 of Set 4 | abu dhabi
# Processing Record 43 of Set 4 | port alfred
# Processing Record 44 of Set 4 | saskylakh
# Processing Record 45 of Set 4 | samana
# Processing Record 46 of Set 4 | rio gallegos
# Processing Record 47 of Set 4 | teya
# Processing Record 48 of Set 4 | satitoa
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 4 | fairbanks
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | olinda
# Processing Record 2 of Set 5 | cape town
# Processing Record 3 of Set 5 | hofn
# Processing Record 4 of Set 5 | chandla
# Processing Record 5 of Set 5 | maine-soroa
# Processing Record 6 of Set 5 | sarkand
# Processing Record 7 of Set 5 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 5 | jiujiang
# Processing Record 9 of Set 5 | cheuskiny
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 5 | charlestown
# Processing Record 11 of Set 5 | souillac
# Processing Record 12 of Set 5 | arcata
# Processing Record 13 of Set 5 | xining
# Processing Record 14 of Set 5 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 5 | taoudenni
# Processing Record 16 of Set 5 | camana
# Processing Record 17 of Set 5 | lavrentiya
# Processing Record 18 of Set 5 | gurlan
# Processing Record 19 of Set 5 | hermanus
# Processing Record 20 of Set 5 | maldonado
# Processing Record 21 of Set 5 | makakilo city
# Processing Record 22 of Set 5 | sandwick
# Processing Record 23 of Set 5 | jaguey grande
# Processing Record 24 of Set 5 | qaqortoq
# Processing Record 25 of Set 5 | aktash
# Processing Record 26 of Set 5 | lida
# Processing Record 27 of Set 5 | tucuman
# Processing Record 28 of Set 5 | hokitika
# Processing Record 29 of Set 5 | ahuimanu
# Processing Record 30 of Set 5 | catuday
# Processing Record 31 of Set 5 | college
# Processing Record 32 of Set 5 | margate
# Processing Record 33 of Set 5 | verkhoyansk
# Processing Record 34 of Set 5 | tuktoyaktuk
# Processing Record 35 of Set 5 | tukrah
# Processing Record 36 of Set 5 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 5 | chokurdakh
# Processing Record 38 of Set 5 | maragogi
# Processing Record 39 of Set 5 | takoradi
# Processing Record 40 of Set 5 | camacha
# Processing Record 41 of Set 5 | thompson
# Processing Record 42 of Set 5 | clyde river
# Processing Record 43 of Set 5 | qui nhon
# Processing Record 44 of Set 5 | macapa
# Processing Record 45 of Set 5 | breytovo
# Processing Record 46 of Set 5 | daru
# Processing Record 47 of Set 5 | lensk
# Processing Record 48 of Set 5 | campeche
# Processing Record 49 of Set 5 | cidreira
# Processing Record 50 of Set 5 | constitucion
# Processing Record 1 of Set 6 | biltine
# Processing Record 2 of Set 6 | arman
# Processing Record 3 of Set 6 | bandarbeyla
# Processing Record 4 of Set 6 | staromaryevka
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 6 | pingzhuang
# Processing Record 6 of Set 6 | windhoek
# Processing Record 7 of Set 6 | morris
# Processing Record 8 of Set 6 | la palma
# Processing Record 9 of Set 6 | nemuro
# Processing Record 10 of Set 6 | treinta y tres
# Processing Record 11 of Set 6 | upernavik
# Processing Record 12 of Set 6 | westpunt
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 6 | mazyr
# Processing Record 14 of Set 6 | mayo
# Processing Record 15 of Set 6 | nhulunbuy
# Processing Record 16 of Set 6 | tarko-sale
# Processing Record 17 of Set 6 | gravdal
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | atlantic city
# Processing Record 20 of Set 6 | carnarvon
# Processing Record 21 of Set 6 | opuwo
# Processing Record 22 of Set 6 | mount gambier
# Processing Record 23 of Set 6 | naucalpan
# Processing Record 24 of Set 6 | zigong
# Processing Record 25 of Set 6 | bilma
# Processing Record 26 of Set 6 | ostrovnoy
# Processing Record 27 of Set 6 | kodiak
# Processing Record 28 of Set 6 | lahan
# Processing Record 29 of Set 6 | shubarkuduk
# Processing Record 30 of Set 6 | airai
# Processing Record 31 of Set 6 | raudeberg
# Processing Record 32 of Set 6 | amarante do maranhao
# Processing Record 33 of Set 6 | grindavik
# Processing Record 34 of Set 6 | truro
# Processing Record 35 of Set 6 | umm lajj
# Processing Record 36 of Set 6 | igarka
# Processing Record 37 of Set 6 | ola
# Processing Record 38 of Set 6 | iberia
# Processing Record 39 of Set 6 | amazar
# Processing Record 40 of Set 6 | jacareacanga
# Processing Record 41 of Set 6 | manokwari
# Processing Record 42 of Set 6 | kamenka
# Processing Record 43 of Set 6 | buala
# Processing Record 44 of Set 6 | festus
# Processing Record 45 of Set 6 | saint-francois
# Processing Record 46 of Set 6 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 6 | pereslavl-zalesskiy
# Processing Record 48 of Set 6 | ornskoldsvik
# Processing Record 49 of Set 6 | chapais
# Processing Record 50 of Set 6 | lasa
# Processing Record 1 of Set 7 | rundu
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | vestbygda
# 'coord'
# City not found. Skipping...
# Processing Record 4 of Set 7 | bandipur
# Processing Record 5 of Set 7 | taburi
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 7 | lagoa
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | catalina foothills
# Processing Record 9 of Set 7 | ati
# Processing Record 10 of Set 7 | beringovskiy
# Processing Record 11 of Set 7 | kumluca
# Processing Record 12 of Set 7 | atherton
# Processing Record 13 of Set 7 | esperance
# Processing Record 14 of Set 7 | puerto lleras
# Processing Record 15 of Set 7 | ituni
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 7 | rocha
# Processing Record 17 of Set 7 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 7 | barrow
# Processing Record 19 of Set 7 | brigantine
# Processing Record 20 of Set 7 | ayan
# Processing Record 21 of Set 7 | nikolsk
# Processing Record 22 of Set 7 | mendoza
# Processing Record 23 of Set 7 | gorno-chuyskiy
# 'coord'
# City not found. Skipping...
# Processing Record 24 of Set 7 | dakoro
# Processing Record 25 of Set 7 | kendari
# Processing Record 26 of Set 7 | fengzhen
# Processing Record 27 of Set 7 | lakota
# Processing Record 28 of Set 7 | xuanzhou
# Processing Record 29 of Set 7 | nakhon thai
# Processing Record 30 of Set 7 | ahipara
# Processing Record 31 of Set 7 | eydhafushi
# Processing Record 32 of Set 7 | palora
# Processing Record 33 of Set 7 | glens falls
# Processing Record 34 of Set 7 | ankazobe
# Processing Record 35 of Set 7 | mentok
# 'coord'
# City not found. Skipping...
# Processing Record 36 of Set 7 | hambantota
# Processing Record 37 of Set 7 | porto velho
# Processing Record 38 of Set 7 | kozluk
# Processing Record 39 of Set 7 | zapolyarnyy
# Processing Record 40 of Set 7 | fort frances
# Processing Record 41 of Set 7 | bambari
# Processing Record 42 of Set 7 | alice springs
# Processing Record 43 of Set 7 | lompoc
# Processing Record 44 of Set 7 | hamilton
# Processing Record 45 of Set 7 | leningradskiy
# Processing Record 46 of Set 7 | sarangani
# Processing Record 47 of Set 7 | nakambala
# Processing Record 48 of Set 7 | urumqi
# Processing Record 49 of Set 7 | sohag
# Processing Record 50 of Set 7 | cardston
# Processing Record 1 of Set 8 | gamba
# Processing Record 2 of Set 8 | nhamunda
# Processing Record 3 of Set 8 | christchurch
# Processing Record 4 of Set 8 | mokhsogollokh
# Processing Record 5 of Set 8 | saint george
# Processing Record 6 of Set 8 | naze
# Processing Record 7 of Set 8 | yeppoon
# Processing Record 8 of Set 8 | los llanos de aridane
# Processing Record 9 of Set 8 | jobabo
# Processing Record 10 of Set 8 | pasni
# Processing Record 11 of Set 8 | westport
# Processing Record 12 of Set 8 | baruun-urt
# Processing Record 13 of Set 8 | krasnoselkup
# Processing Record 14 of Set 8 | northam
# Processing Record 15 of Set 8 | necochea
# Processing Record 16 of Set 8 | nanortalik
# Processing Record 17 of Set 8 | los alamos
# Processing Record 18 of Set 8 | peru
# Processing Record 19 of Set 8 | ouadda
# Processing Record 20 of Set 8 | mahajanga
# Processing Record 21 of Set 8 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 8 | namatanai
# Processing Record 23 of Set 8 | oksfjord
# Processing Record 24 of Set 8 | hailey
# Processing Record 25 of Set 8 | port-gentil
# Processing Record 26 of Set 8 | evensk
# Processing Record 27 of Set 8 | korla
# Processing Record 28 of Set 8 | matadi
# Processing Record 29 of Set 8 | agva
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 8 | cairns
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | betare oya
# Processing Record 33 of Set 8 | roebourne
# Processing Record 34 of Set 8 | mirnyy
# Processing Record 35 of Set 8 | altamira
# Processing Record 36 of Set 8 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 37 of Set 8 | tarakan
# Processing Record 38 of Set 8 | natal
# Processing Record 39 of Set 8 | santiago de cao
# Processing Record 40 of Set 8 | russkaya polyana
# Processing Record 41 of Set 8 | ciampino
# Processing Record 42 of Set 8 | ouallam
# Processing Record 43 of Set 8 | serafimovskiy
# Processing Record 44 of Set 8 | knysna
# Processing Record 45 of Set 8 | thinadhoo
# Processing Record 46 of Set 8 | byron bay
# Processing Record 47 of Set 8 | ilulissat
# Processing Record 48 of Set 8 | muzhi
# Processing Record 49 of Set 8 | majene
# Processing Record 50 of Set 8 | thunder bay
# Processing Record 1 of Set 9 | bacolod
# Processing Record 2 of Set 9 | tsogni
# Processing Record 3 of Set 9 | japura
# Processing Record 4 of Set 9 | viligili
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 9 | buraydah
# Processing Record 6 of Set 9 | whitianga
# Processing Record 7 of Set 9 | nouadhibou
# Processing Record 8 of Set 9 | puerto ayacucho
# Processing Record 9 of Set 9 | boguchar
# Processing Record 10 of Set 9 | pinawa
# Processing Record 11 of Set 9 | anjiang
# Processing Record 12 of Set 9 | pangai
# Processing Record 13 of Set 9 | lae
# Processing Record 14 of Set 9 | nyurba
# Processing Record 15 of Set 9 | kachikau
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 9 | ulaanbaatar
# Processing Record 17 of Set 9 | port blair
# Processing Record 18 of Set 9 | sakhipur
# Processing Record 19 of Set 9 | palana
# Processing Record 20 of Set 9 | mitha tiwana
# Processing Record 21 of Set 9 | yelizovo
# Processing Record 22 of Set 9 | duvan
# Processing Record 23 of Set 9 | guerrero negro
# Processing Record 24 of Set 9 | tungkang
# 'coord'
# City not found. Skipping...
# Processing Record 25 of Set 9 | pevek
# Processing Record 26 of Set 9 | semporna
# Processing Record 27 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 9 | altamont
# Processing Record 29 of Set 9 | la asuncion
# Processing Record 30 of Set 9 | eenhana
# Processing Record 31 of Set 9 | inverell
# Processing Record 32 of Set 9 | morant bay
# Processing Record 33 of Set 9 | powell
# Processing Record 34 of Set 9 | pueblo
# Processing Record 35 of Set 9 | yeniseysk
# Processing Record 36 of Set 9 | medicine hat
# Processing Record 37 of Set 9 | soderhamn
# Processing Record 38 of Set 9 | saint anthony
# Processing Record 39 of Set 9 | tambovka
# Processing Record 40 of Set 9 | meadow lake
# Processing Record 41 of Set 9 | kerteh
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 9 | masalli
# Processing Record 43 of Set 9 | kristallopiyi
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 9 | pandelys
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 9 | lazarev
# Processing Record 46 of Set 9 | bo phloi
# Processing Record 47 of Set 9 | san nicolas
# Processing Record 48 of Set 9 | kindu
# Processing Record 49 of Set 9 | pinega
# Processing Record 50 of Set 9 | jieshi
# Processing Record 1 of Set 10 | huaicheng
# Processing Record 2 of Set 10 | dire dawa
# Processing Record 3 of Set 10 | escanaba
# Processing Record 4 of Set 10 | tvoroyri
# Processing Record 5 of Set 10 | moree
# Processing Record 6 of Set 10 | valparaiso
# Processing Record 7 of Set 10 | lorengau
# Processing Record 8 of Set 10 | batemans bay
# Processing Record 9 of Set 10 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 10 | vieux-habitants
# Processing Record 11 of Set 10 | porto novo
# Processing Record 12 of Set 10 | aitape
# Processing Record 13 of Set 10 | skalistyy
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 10 | sao jose da coroa grande
# Processing Record 15 of Set 10 | auki
# Processing Record 16 of Set 10 | sao filipe
# Processing Record 17 of Set 10 | greer
# Processing Record 18 of Set 10 | shimoda
# Processing Record 19 of Set 10 | port hardy
# Processing Record 20 of Set 10 | tlahualilo
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 10 | stege
# Processing Record 22 of Set 10 | zaton
# Processing Record 23 of Set 10 | faya
# Processing Record 24 of Set 10 | honningsvag
# Processing Record 25 of Set 10 | kobojango
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 10 | kinkala
# Processing Record 27 of Set 10 | abakaliki
# Processing Record 28 of Set 10 | simao
# Processing Record 29 of Set 10 | havoysund
# Processing Record 30 of Set 10 | wonthaggi
# Processing Record 31 of Set 10 | santa maria
# Processing Record 32 of Set 10 | port macquarie
# Processing Record 33 of Set 10 | sistranda
# Processing Record 34 of Set 10 | salo
# Processing Record 35 of Set 10 | ladushkin
# Processing Record 36 of Set 10 | mogadishu
# Processing Record 37 of Set 10 | traverse city
# Processing Record 38 of Set 10 | whitehorse
# Processing Record 39 of Set 10 | wakkanai
# Processing Record 40 of Set 10 | at-bashi
# Processing Record 41 of Set 10 | gurskoye
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 10 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 10 | paamiut
# Processing Record 44 of Set 10 | baykit
# Processing Record 45 of Set 10 | kerema
# Processing Record 46 of Set 10 | moerai
# Processing Record 47 of Set 10 | palmer
# Processing Record 48 of Set 10 | los angeles
# Processing Record 49 of Set 10 | huarmey
# Processing Record 50 of Set 10 | tarabha
# Processing Record 1 of Set 11 | aksu
# Processing Record 2 of Set 11 | caravelas
# Processing Record 3 of Set 11 | laguna
# Processing Record 4 of Set 11 | rondonopolis
# Processing Record 5 of Set 11 | voh
# Processing Record 6 of Set 11 | cayenne
# Processing Record 7 of Set 11 | dayong
# Processing Record 8 of Set 11 | camalu
# Processing Record 9 of Set 11 | kamiiso
# Processing Record 10 of Set 11 | tete
# Processing Record 11 of Set 11 | labuhan
# Processing Record 12 of Set 11 | pisco
# Processing Record 13 of Set 11 | komsomolskiy
# Processing Record 14 of Set 11 | innisfail
# Processing Record 15 of Set 11 | shumyachi
# Processing Record 16 of Set 11 | along
# Processing Record 17 of Set 11 | batagay-alyta
# Processing Record 18 of Set 11 | jaltenango
# Processing Record 19 of Set 11 | casablanca
# Processing Record 20 of Set 11 | hurricane
# Processing Record 21 of Set 11 | mumbwa
# Processing Record 22 of Set 11 | puerto del rosario
# Processing Record 23 of Set 11 | acapulco
# Processing Record 24 of Set 11 | walvis bay
# Processing Record 25 of Set 11 | yulara
# Processing Record 26 of Set 11 | tripoli
# Processing Record 27 of Set 11 | bargal
# 'coord'
# City not found. Skipping...
# Processing Record 28 of Set 11 | bannu
# Processing Record 29 of Set 11 | coihaique
# Processing Record 30 of Set 11 | honiara
# Processing Record 31 of Set 11 | ugoofaaru
# Processing Record 32 of Set 11 | vagur
# Processing Record 33 of Set 11 | koudougou
# Processing Record 34 of Set 11 | jiuquan
# Processing Record 35 of Set 11 | gogrial
# Processing Record 36 of Set 11 | baghmara
# Processing Record 37 of Set 11 | almaznyy
# Processing Record 38 of Set 11 | moose factory
# Processing Record 39 of Set 11 | burns lake
# Processing Record 40 of Set 11 | strazske
# Processing Record 41 of Set 11 | hay river
# Processing Record 42 of Set 11 | oranjemund
# Processing Record 43 of Set 11 | marawi
# Processing Record 44 of Set 11 | calama
# Processing Record 45 of Set 11 | yerbogachen
# Processing Record 46 of Set 11 | villa rica
# Processing Record 47 of Set 11 | monrovia
# Processing Record 48 of Set 11 | ridgecrest
# Processing Record 49 of Set 11 | kayes
# Processing Record 50 of Set 11 | oktyabrskiy
# Processing Record 1 of Set 12 | hammerfest
# Processing Record 2 of Set 12 | tura
# Processing Record 3 of Set 12 | sterling
# Processing Record 4 of Set 12 | puerto quijarro
# Processing Record 5 of Set 12 | cockburn town
# Processing Record 6 of Set 12 | san rafael
# Processing Record 7 of Set 12 | oktyabrskoye
# Processing Record 8 of Set 12 | sagua la grande
# Processing Record 9 of Set 12 | jackson
# Processing Record 10 of Set 12 | uvat
# Processing Record 11 of Set 12 | timizart
# Processing Record 12 of Set 12 | nicoya
# Processing Record 13 of Set 12 | nsanje
# Processing Record 14 of Set 12 | nizhniy kuranakh
# Processing Record 15 of Set 12 | doctor pedro p. pena
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 12 | termini imerese
# Processing Record 17 of Set 12 | chany
# Processing Record 18 of Set 12 | beboto
# Processing Record 19 of Set 12 | san mateo del mar
# Processing Record 20 of Set 12 | peniche
# Processing Record 21 of Set 12 | talcahuano
# Processing Record 22 of Set 12 | dalvik
# Processing Record 23 of Set 12 | jiazi
# Processing Record 24 of Set 12 | vao
# Processing Record 25 of Set 12 | sorbhog
# Processing Record 26 of Set 12 | mehamn
# Processing Record 27 of Set 12 | swan river
# Processing Record 28 of Set 12 | yumen
# Processing Record 29 of Set 12 | cuamba
# Processing Record 30 of Set 12 | khilok
# Processing Record 31 of Set 12 | lingao
# Processing Record 32 of Set 12 | kodinsk
# Processing Record 33 of Set 12 | axim
# Processing Record 34 of Set 12 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 12 | markova
# Processing Record 36 of Set 12 | arecibo
# Processing Record 37 of Set 12 | meulaboh
# Processing Record 38 of Set 12 | sosnovo-ozerskoye
# Processing Record 39 of Set 12 | tagusao
# Processing Record 40 of Set 12 | panzhihua
# Processing Record 41 of Set 12 | san patricio
# Processing Record 42 of Set 12 | de aar
# Processing Record 43 of Set 12 | svetlogorsk
# Processing Record 44 of Set 12 | isangel
# Processing Record 45 of Set 12 | cedar city
# Processing Record 46 of Set 12 | gerash
# Processing Record 47 of Set 12 | montepuez
# Processing Record 48 of Set 12 | benguela
# Processing Record 49 of Set 12 | andevoranto
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 12 | changping
# Processing Record 1 of Set 13 | adrar
# Processing Record 2 of Set 13 | sayyan
# Processing Record 3 of Set 13 | mahina
# Processing Record 4 of Set 13 | opobo
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 13 | kashi
# Processing Record 6 of Set 13 | haibowan
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 13 | gidole
# Processing Record 8 of Set 13 | batagay
# Processing Record 9 of Set 13 | hami
# Processing Record 10 of Set 13 | da lat
# Processing Record 11 of Set 13 | taltal
# Processing Record 12 of Set 13 | kuching
# Processing Record 13 of Set 13 | iranshahr
# Processing Record 14 of Set 13 | winnemucca
# Processing Record 15 of Set 13 | leh
# Processing Record 16 of Set 13 | santa rosa
# Processing Record 17 of Set 13 | melfi
# Processing Record 18 of Set 13 | jumla
# Processing Record 19 of Set 13 | severnyy
# Processing Record 20 of Set 13 | mitchell
# Processing Record 21 of Set 13 | dawson creek
# Processing Record 22 of Set 13 | celestun
# Processing Record 23 of Set 13 | moa
# Processing Record 24 of Set 13 | okhotsk
# Processing Record 25 of Set 13 | chulman
# Processing Record 26 of Set 13 | kamaishi
# Processing Record 27 of Set 13 | haimen
# Processing Record 28 of Set 13 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 13 | eureka
# Processing Record 30 of Set 13 | taga
# Processing Record 31 of Set 13 | chicama
# Processing Record 32 of Set 13 | sergeyevka
# Processing Record 33 of Set 13 | flinders
# Processing Record 34 of Set 13 | ukhta
# Processing Record 35 of Set 13 | rumuruti
# Processing Record 36 of Set 13 | manzanillo
# Processing Record 37 of Set 13 | portoferraio
# Processing Record 38 of Set 13 | lubsko
# Processing Record 39 of Set 13 | kupang
# Processing Record 40 of Set 13 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 13 | aykhal
# Processing Record 42 of Set 13 | manta
# Processing Record 43 of Set 13 | udachnyy
# Processing Record 44 of Set 13 | mataram
# Processing Record 45 of Set 13 | carauari
# Processing Record 46 of Set 13 | harper
# Processing Record 47 of Set 13 | tutoia
# Processing Record 48 of Set 13 | grimari
# 'coord'
# City not found. Skipping...
# Processing Record 49 of Set 13 | saint-augustin
# Processing Record 50 of Set 13 | falealupo
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 14 | skibbereen
# Processing Record 2 of Set 14 | nioki
# Processing Record 3 of Set 14 | guayaramerin
# Processing Record 4 of Set 14 | bonthe
# Processing Record 5 of Set 14 | hunza
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 14 | prado
# Processing Record 7 of Set 14 | mandurah
# Processing Record 8 of Set 14 | constantine
# Processing Record 9 of Set 14 | sena madureira
# Processing Record 10 of Set 14 | suure-jaani
# Processing Record 11 of Set 14 | krasnorechenskiy
# Processing Record 12 of Set 14 | yuli
# Processing Record 13 of Set 14 | muzquiz
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 14 | azimur
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 14 | major isidoro
# Processing Record 16 of Set 14 | guozhen
# Processing Record 17 of Set 14 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 14 | tirano
# Processing Record 19 of Set 14 | bintulu
# Processing Record 20 of Set 14 | vila franca do campo
# Processing Record 21 of Set 14 | solginskiy
# Processing Record 22 of Set 14 | calvia
# Processing Record 23 of Set 14 | stornoway
# Processing Record 24 of Set 14 | south venice
# Processing Record 25 of Set 14 | vardo
# Processing Record 26 of Set 14 | santa marta
# Processing Record 27 of Set 14 | araouane
# Processing Record 28 of Set 14 | usak
# Processing Record 29 of Set 14 | oxbow
# Processing Record 30 of Set 14 | turukhansk
# Processing Record 31 of Set 14 | kawalu
# Processing Record 32 of Set 14 | polunochnoye
# Processing Record 33 of Set 14 | basco
# Processing Record 34 of Set 14 | ulvila
# Processing Record 35 of Set 14 | bereda
# Processing Record 36 of Set 14 | alyangula
# Processing Record 37 of Set 14 | moen
# Processing Record 38 of Set 14 | graaff-reinet
# Processing Record 39 of Set 14 | sampit
# Processing Record 40 of Set 14 | san lorenzo
# Processing Record 41 of Set 14 | bubaque
# Processing Record 42 of Set 14 | puerto escondido
# Processing Record 43 of Set 14 | namibe
# Processing Record 44 of Set 14 | sabha
# Processing Record 45 of Set 14 | emerald
# Processing Record 46 of Set 14 | zlocieniec
# Processing Record 47 of Set 14 | ojinaga
# Processing Record 48 of Set 14 | sembe
# Processing Record 49 of Set 14 | kunashak
# Processing Record 50 of Set 14 | boffa
# Processing Record 1 of Set 15 | karasburg
# Processing Record 2 of Set 15 | gat
# Processing Record 3 of Set 15 | hun
# Processing Record 4 of Set 15 | trairi
# Processing Record 5 of Set 15 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 15 | thiruvananthapuram
# Processing Record 7 of Set 15 | tambul
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 15 | boo
# Processing Record 9 of Set 15 | kavieng
# Processing Record 10 of Set 15 | brigham city
# Processing Record 11 of Set 15 | grand centre
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 15 | nabire
# Processing Record 13 of Set 15 | abnub
# Processing Record 14 of Set 15 | nagato
# Processing Record 15 of Set 15 | port hedland
# Processing Record 16 of Set 15 | bagotville
# Processing Record 17 of Set 15 | sargatskoye
# Processing Record 18 of Set 15 | obo
# Processing Record 19 of Set 15 | fevralsk
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 15 | bahar
# Processing Record 21 of Set 15 | biak
# Processing Record 22 of Set 15 | hualmay
# Processing Record 23 of Set 15 | bayji
# Processing Record 24 of Set 15 | sahuaripa
# Processing Record 25 of Set 15 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 15 | pyu
# Processing Record 27 of Set 15 | centralia
# Processing Record 28 of Set 15 | tecoanapa
# Processing Record 29 of Set 15 | birakan
# Processing Record 30 of Set 15 | khudumelapye
# Processing Record 31 of Set 15 | zeya
# Processing Record 32 of Set 15 | san cristobal
# Processing Record 33 of Set 15 | praya
# Processing Record 34 of Set 15 | santa cruz
# Processing Record 35 of Set 15 | kirakira
# Processing Record 36 of Set 15 | sobolevo
# Processing Record 37 of Set 15 | nome
# Processing Record 38 of Set 15 | popondetta
# Processing Record 39 of Set 15 | mercedes
# Processing Record 40 of Set 15 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 41 of Set 15 | broken hill
# Processing Record 42 of Set 15 | tidore
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 15 | kuteynykove
# Processing Record 44 of Set 15 | santa marinella
# Processing Record 45 of Set 15 | kitimat
# Processing Record 46 of Set 15 | maltahohe
# Processing Record 47 of Set 15 | rafiganj
# Processing Record 48 of Set 15 | ust-maya
# Processing Record 49 of Set 15 | great yarmouth
# Processing Record 50 of Set 15 | colares
# Processing Record 1 of Set 16 | baturaja
# Processing Record 2 of Set 16 | ban nahin
# Processing Record 3 of Set 16 | aylesbury
# Processing Record 4 of Set 16 | verkhnetulomskiy
# Processing Record 5 of Set 16 | quatre cocos
# Processing Record 6 of Set 16 | vagamo
# Processing Record 7 of Set 16 | duz
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 16 | havre-saint-pierre
# Processing Record 9 of Set 16 | letnyaya stavka
# Processing Record 10 of Set 16 | omboue
# Processing Record 11 of Set 16 | klaksvik
# Processing Record 12 of Set 16 | shostka
# Processing Record 13 of Set 16 | pafos
# Processing Record 14 of Set 16 | ambulu
# Processing Record 15 of Set 16 | port perry
# Processing Record 16 of Set 16 | zaozerne
# Processing Record 17 of Set 16 | rodrigues alves
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 697

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Yellowknife  62.46 -114.35     17.60        85          90        8.05
# 1  Mar Del Plata -38.00  -57.56     66.20        59           0       10.29
# 2   Puerto Ayora  -0.74  -90.35     78.80        69          40       13.87
# 3          Kutum  14.20   24.67     76.19        25          50       17.29
# 4       Imbituba -28.24  -48.67     68.00        56          40       11.41
# 5        Qaanaaq  77.48  -69.36      1.29        74           0        7.58
# 6          Avera  33.19  -82.53     70.00        60          40       13.87
# 7         Rawson -43.30  -65.10     96.80         6          40       18.34
# 8       Saldanha -33.01   17.94     68.00        56           0        5.82
# 9   Richards Bay -28.78   32.04     65.14        85         100        4.21
#
#   Country Current Description
# 0      CA          light snow
# 1      AR           clear sky
# 2      EC    scattered clouds
# 3      SD    scattered clouds
# 4      BR    scattered clouds
# 5      GL           clear sky
# 6      US    scattered clouds
# 7      AR    scattered clouds
# 8      ZA           clear sky
# 9      ZA          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]

# %%
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#             City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0    Yellowknife      CA  62.46 -114.35     17.60        85          90
# 1  Mar Del Plata      AR -38.00  -57.56     66.20        59           0
# 2   Puerto Ayora      EC  -0.74  -90.35     78.80        69          40
# 3          Kutum      SD  14.20   24.67     76.19        25          50
# 4       Imbituba      BR -28.24  -48.67     68.00        56          40
# 5        Qaanaaq      GL  77.48  -69.36      1.29        74           0
# 6          Avera      US  33.19  -82.53     70.00        60          40
# 7         Rawson      AR -43.30  -65.10     96.80         6          40
# 8       Saldanha      ZA -33.01   17.94     68.00        56           0
# 9   Richards Bay      ZA -28.78   32.04     65.14        85         100
#
#    Wind Speed Current Description
# 0        8.05          light snow
# 1       10.29           clear sky
# 2       13.87    scattered clouds
# 3       17.29    scattered clouds
# 4       11.41    scattered clouds
# 5        7.58           clear sky
# 6       13.87    scattered clouds
# 7       18.34    scattered clouds
# 8        5.82           clear sky
# 9        4.21          light rain

# %%
# Create the output file (CSV)
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV
city_data_df.to_csv(output_data_file, index_label='City_ID')
